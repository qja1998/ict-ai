# %%
import os
import numpy as np
import matplotlib.pylab as plt

# %%
path = '.'
data_path = path + '/data'

# %%
file_list = os.listdir(data_path + "/test_npy")
test_npy = [np.load(data_path + "/test_npy/" + npy) for npy in file_list]

# %%
for test in test_npy[10:20]:
    plt.figure(figsize=(20, 10))
    plt.imshow(test)
